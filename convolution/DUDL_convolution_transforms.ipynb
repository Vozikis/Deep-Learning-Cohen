# %% [markdown]
# # COURSE: A deep understanding of deep learning
# ## SECTION: Convolution and transformations
# ### LECTURE: Image transformations
# #### TEACHER: Mike X Cohen, sincxpress.com
# ##### COURSE URL: udemy.com/course/deeplearning_x/?couponCode=202212

# %%
# import libraries
import numpy as np
import torch 

# NEW!
import torchvision
import torchvision.transforms as T
from PIL import Image
import matplotlib.pyplot as plt
from IPython import display
display.set_matplotlib_formats('svg')
# Out:
# /var/folders/f2/gq8xgm9x491cqwtct_tgpy0h0000gn/T/ipykernel_71081/2962403297.py:11: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   display.set_matplotlib_formats('svg')

# %% [markdown]
# # Import a dataset

# %%
# The list of datasets that come with torchvision: https://pytorch.org/vision/stable/index.html

# %%
# download the CIFAR10 dataset
cdata = torchvision.datasets.CIFAR10(root='cifar10', download=True)

print(cdata)
# Out:
# Files already downloaded and verified
# Dataset CIFAR10
#     Number of datapoints: 50000
#     Split: train
#     Root Location: cifar10
#     Transforms (if any): None
#     Target Transforms (if any): None

# %%
# check out the shape of the dataset
print( cdata.data.shape )

# the unique categories
print( cdata.classes ) #show all the classes available

# .targets is a list of targets converted to ints
print( len(cdata.targets) )
# Out:
# (50000, 32, 32, 3)
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# 50000

# %%
# inspect a few random images

fig,axs = plt.subplots(5,5,figsize=(10,10))

for ax in axs.flatten():#loop in all of them

  # select a random picture
  randidx = np.random.choice(len(cdata.targets))

  # extract that image
  pic = cdata.data[randidx,:,:,:]
  # and its label
  label = cdata.classes[cdata.targets[randidx]]

  # and show!
  ax.imshow(pic)
  ax.text(16,0,label,ha='center',fontweight='bold',color='k',backgroundcolor='y')
  ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Apply some transformations

# %%
Ts = T.Compose([ T.ToPILImage(),
                 T.ToTensor(),
                 T.Resize(32*4), #increase the resolution of the images by a factor of 4
                 T.Grayscale(num_output_channels=1)  ]) #convert to grayscale

# include the transform in the dataset
cdata.transform = Ts

# you can also apply the transforms immediately when loading in the data
# cdata = torchvision.datasets.CIFAR10(root='cifar10', download=True, transform=Ts)


# Important! Adding a transform doesn't change the image data:
print(cdata.data[123,:,:,:].shape)
# Out:
# (32, 32, 3)

# %%
# apply the transform

# option 1a: apply the transform "externally" to an image
img1 = Ts( cdata.data[123,:,:,:] )

# option 1b: use the embedded transform
img2 = cdata.transform( cdata.data[123,:,:,:] )

img1.toPILimage()
# let's see what we've done!
fig,ax = plt.subplots(1,3,figsize=(10,3))
ax[0].imshow(cdata.data[123,:,:,:])
ax[1].imshow(torch.squeeze(img1))
ax[2].imshow(torch.squeeze(img2),cmap='gray')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [50], line 4
#       1 # apply the transform
#       2
#       3 # option 1a: apply the transform "externally" to an image
# ----> 4 img1 = Ts( cdata.data[123,:,:,:] )
#       6 # option 1b: use the embedded transform
#       7 img2 = cdata.transform( cdata.data[123,:,:,:] )
#
# File ~/miniforge3/envs/dfl_test/lib/python3.8/site-packages/torchvision/transforms/transforms.py:60, in Compose.__call__(self, img)
#      58 def __call__(self, img):
#      59     for t in self.transforms:
# ---> 60         img = t(img)
#      61     return img
#
# File ~/miniforge3/envs/dfl_test/lib/python3.8/site-packages/torchvision/transforms/transforms.py:195, in Resize.__call__(self, img)
#     187 def __call__(self, img):
#     188     """
#     189     Args:
#     190         img (PIL Image): Image to be scaled.
#    (...)
#     193         PIL Image: Rescaled image.
#     194     """
# --> 195     return F.resize(img, self.size, self.interpolation)
#
# File ~/miniforge3/envs/dfl_test/lib/python3.8/site-packages/torchvision/transforms/functional.py:229, in resize(img, size, interpolation)
#     213 r"""Resize the input PIL Image to the given size.
#     214
#     215 Args:
#    (...)
#     226     PIL Image: Resized image.
#     227 """
#     228 if not _is_pil_image(img):
# --> 229     raise TypeError('img should be PIL Image. Got {}'.format(type(img)))
#     230 if not (isinstance(size, int) or (isinstance(size, Iterable) and len(size) == 2)):
#     231     raise TypeError('Got inappropriate size arg: {}'.format(size))
#
# TypeError: img should be PIL Image. Got <class 'torch.Tensor'>

# %%
# Note about ToTensor() and normalization:
??T.ToTensor()
# Out:
# Object `T.ToTensor()` not found.

# %% [markdown]
# # Additional explorations

# %%
# 1) There are many other transforms available in torchvision: https://pytorch.org/vision/stable/transforms.html
#    Many transformations are useful for data preparation and augmentation. We'll cover some of them later in the course,
#    but for now, read about RandomCrop(), RandomHorizontalFlip(), and CenterCrop(). Then implement them to understand 
#    what they do to images.
#    Tip: It's probably best to test these transforms separately, and on one test image, as we did above.
#
